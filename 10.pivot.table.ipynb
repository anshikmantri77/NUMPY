# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Administrator\\OneDrive\\Desktop\\python\\citywise_weather.csv")
df
# Out:
#           day   city  temperature  windspeed   event
# 0  01-01-2017  delhi           38          6   sunny
# 1  01-02-2017  delhi           41          5   sunny
# 2  01-03-2017  delhi           40          7    rain
# 3  01-01-2017  paris           25          8    rain
# 4  01-02-2017  paris           26          9  cloudy
# 5  01-03-2017  paris           29         10   sunny
# 6  01-01-2017   rome           19          5  cloudy
# 7  01-02-2017   rome           21          6    rain
# 8  01-03-2017   rome           20          4  cloudy

# %%
df.pivot(index="day",columns="city",values=["temperature","event"])
# Out:
#            temperature             event
# city             delhi paris rome  delhi   paris    rome
# day
# 01-01-2017          38    25   19  sunny    rain  cloudy
# 01-02-2017          41    26   21  sunny  cloudy    rain
# 01-03-2017          40    29   20   rain   sunny  cloudy

# %%
df=pd.read_csv("C:\\Users\\Administrator\\OneDrive\\Desktop\\python\\weather2.csv")
df
# Out:
#          date  city   temperature  humidity
# 0  05-01-2000  delhi           32        43
# 1  05-01-2000  delhi           21        56
# 2  05-02-2000  delhi           23        32
# 3  05-02-2000  delhi           45        45
# 4  05-01-2000  paris           23        44
# 5  05-01-2000  paris           45        33
# 6  05-02-2000  paris           23        41
# 7  05-02-2000  paris           30        40

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:8718, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8701 @Substitution("")
#    8702 @Appender(_shared_docs["pivot_table"])
#    8703 def pivot_table(
#    (...)
#    8714     sort=True,
#    8715 ) -> DataFrame:
#    8716     from pandas.core.reshape.pivot import pivot_table
# -> 8718     return pivot_table(
#    8719         self,
#    8720         values=values,
#    8721         index=index,
#    8722         columns=columns,
#    8723         aggfunc=aggfunc,
#    8724         fill_value=fill_value,
#    8725         margins=margins,
# ...
